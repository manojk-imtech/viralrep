# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Done_6639/heatmap/Coronaviridaceae/coronaviridaceae_heatmap_input.csv", index_col=0)
data.head()
# Out:
#          Fostamatinib  Chlorpromazine  Mycophenolate mofetil  Etidronic acid  \
# Viruses
# nCoV-19           1.0             1.0                    1.0             1.0
# SARS              NaN             NaN                    NaN             NaN
# MERS              NaN             NaN                    NaN             NaN
#
#          Sorafenib  Regorafenib  Amoxapine  Aripiprazole  Loxapine  \
# Viruses
# nCoV-19        0.4          0.4       0.89          0.83      0.83
# SARS           NaN          NaN        NaN           NaN       NaN
# MERS           NaN          NaN        NaN           NaN       NaN
#
#          Pimecrolimus  ...  Trimethoprim  Fluorouracil  Methotrexate  \
# Viruses                ...
# nCoV-19          0.67  ...           NaN           NaN           NaN
# SARS              NaN  ...           NaN           NaN           NaN
# MERS              NaN  ...           0.5           0.5           0.5
#
# ...

# %%
sns.set(font_scale=1.8)
#ax=sns.heatmap(data,linewidths=0.001,linecolor="k",  cmap="YlGnBu")
plt.figure(figsize=(40,2.5))
ax=sns.heatmap(data,linecolor="k",linewidths=0.004,  cmap="Spectral")
